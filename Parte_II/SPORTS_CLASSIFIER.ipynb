# %% [markdown]
# # Clasificador de deportes con Keras
#
#
# ### Clases disponibles:
#
# * lacrosse
# * shuffleboard
# * arm wrestling
# * golf
# * surfing
# * snow boarding
# * parallel bar
# * pole climbing
# * giant slalom
# * bobsled
# * baton twirling
# * weightlifting
# * hydroplane racing
# * barell racing
# * water cycling
# * mushing
# * uneven bars
# * pole vault
# * roller derby
# * rowing
# * jousting
# * air hockey
# * sky surfing
# * shot put
# * sidecar racing
# * field hockey
# * harness racing
# * disc golf
# * canoe slamon
# * football
# * ski jumping
# * ice yachting
# * cricket
# * figure skating women
# * horse racing
# * baseball
# * billiards
# * bowling
# * motorcycle racing
# * javelin
# * fly fishing
# * bull riding
# * sumo wrestling
# * tug of war
# * figure skating men
# * sailboat racing
# * horse jumping
# * basketball
# * cheerleading
# * frisbee
# * high jump
# * water polo
# * polo
# * rock climbing
# * rollerblade racing
# * figure skating pairs
# * balance beam
# * formula 1 racing
# * volleyball
# * hang gliding
# * ultimate
# * croquet
# * table tennis
# * rugby
# * fencing
# * ampute football
# * nascar racing
# * hockey
# * pommel horse
# * wingsuit flying
# * jai alai
# * hammer throw
# * steer wrestling
# * swimming
# * luge
# * wheelchair basketball
# * tennis
# * bungee jumping
# * rings
# * bmx
# * wheelchair racing
# * trapeze
# * archery
# * curling
# * skydiving
# * log rolling
# * boxing
# * olympic wrestling
# * bike polo
# * snowmobile racing
# * axe throwing
# * judo
# * ice climbing
# * gaga
# * pole dancing
# * track bicycle
# * chuckwagon racing
# * hurdles
# * horseshoe pitching
# * speed skating
#
# Resolución de imagen original: **224x224** px

# %%
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-02-27 18:57:39.717716: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Preprocesamiento de las imágenes
#
# Lo primero que vamos a hacer es leer el dataset de imagenes y convertir todas ellas **224x224** px con una profundidad de color de **0-255**

# %%
DATADIR = "/Users/albert99/Desktop/Proyectos/DATASETS/sports/"

CATEGORIES = [
    "lacrosse",
    "shuffleboard",
    "arm wrestling",
    "golf",
    "surfing",
    "snow boarding",
    "parallel bar",
    "pole climbing",
    "giant slalom",
    "bobsled",
    "baton twirling",
    "weightlifting",
    "hydroplane racing",
    "barell racing",
    "water cycling",
    "mushing",
    "uneven bars",
    "pole vault",
    "roller derby",
    "rowing",
    "jousting",
    "air hockey",
    "sky surfing",
    "shot put",
    "sidecar racing",
    "field hockey",
    "harness racing",
    "disc golf",
    "canoe slamon",
    "football",
    "ski jumping",
    "ice yachting",
    "cricket",
    "figure skating women",
    "horse racing",
    "baseball",
    "billiards",
    "bowling",
    "motorcycle racing",
    "javelin",
    "fly fishing",
    "bull riding",
    "sumo wrestling",
    "tug of war",
    "figure skating men",
    "sailboat racing",
    "horse jumping",
    "basketball",
    "cheerleading",
    "frisbee",
    "high jump",
    "water polo",
    "polo",
    "rock climbing",
    "rollerblade racing",
    "figure skating pairs",
    "balance beam",
    "formula 1 racing",
    "volleyball",
    "hang gliding",
    "ultimate",
    "croquet",
    "table tennis",
    "rugby",
    "fencing",
    "ampute football",
    "nascar racing",
    "hockey",
    "pommel horse",
    "wingsuit flying",
    "jai alai",
    "hammer throw",
    "steer wrestling",
    "swimming",
    "luge",
    "wheelchair basketball",
    "tennis",
    "bungee jumping",
    "rings",
    "bmx",
    "wheelchair racing",
    "trapeze",
    "archery",
    "curling",
    "skydiving",
    "log rolling",
    "boxing",
    "olympic wrestling",
    "bike polo",
    "snowmobile racing",
    "axe throwing",
    "judo",
    "ice climbing",
    "gaga",
    "pole dancing",
    "track bicycle",
    "chuckwagon racing",
    "hurdles",
    "horseshoe pitching",
    "speed skating"
]

CATEGORIES = [
    "lacrosse",
    "shuffleboard"
]

# %%
def preprocessing_data(DATADIR, CATEGORIES, training_data, IMG_SIZE_X, IMG_SIZE_Y, CATEGORIES_DICT={}):
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        
        # asignar valor numérico a cada categoría (one-hot encoding
        class_num = CATEGORIES.index(category)
        CATEGORIES_DICT[category] = str(class_num) # agregarlo al diccionario
        
        print("CAT: " + category + " | OHE: -> " + str(class_num))
        cont_img = 0
        
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)            
                # redimensionar la imagen
                new_array = cv2.resize(img_array, (IMG_SIZE_X, IMG_SIZE_Y))
                # agregar a la lista
                training_data.append([new_array, class_num])
                # control
                cont_img=cont_img+1
                print("          PROC: " + os.path.join(path, img))
            
            except Exception:
                pass

        print("     TOTAL PROCESADO -> " + str(cont_img) + "/" + str(len(os.listdir(path))) )
        
    print("PREPROCESAMIENTO FINALIZADO CON ÉXITO!")

    
training_data = []
valid_data = []
test_data = []

CATEGORIES_DICT = {} # diccionario que relaciona <nombre_categoria>,<numero_asociado>

IMG_SIZE = 100

# %%
# Preprocesado de datos de entrenamiento
preprocessing_data(DATADIR+"train", CATEGORIES, training_data, IMG_SIZE, IMG_SIZE, CATEGORIES_DICT)

# Preprocesado de datos de validación
preprocessing_data(DATADIR+"valid", CATEGORIES, valid_data, IMG_SIZE, IMG_SIZE)

# Preprocesado de datos de test
preprocessing_data(DATADIR+"test", CATEGORIES, test_data, IMG_SIZE, IMG_SIZE)
# Out:
# CAT: lacrosse | OHE: -> 0
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/016.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/002.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/003.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/017.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/149.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/029.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/001.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/015.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/014.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/028.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/148.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/004.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/010.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/038.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/039.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/011.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/005.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/013.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/007.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/006.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/012.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/129.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/101.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/115.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/049.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/075.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/061.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/060.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/074.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/048.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/114.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/100.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/128.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/116.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/102.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/089.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/062.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/076.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/077.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/063.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/088.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/103.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/117.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/113.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/107.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/098.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/067.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/073.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/072.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/066.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/099.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/106.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/112.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/104.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/110.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/138.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/070.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/064.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/058.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/059.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/065.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/071.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/139.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/111.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/105.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/108.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/120.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/134.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/097.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/083.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/068.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/054.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/040.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/041.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/055.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/069.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/082.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/096.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/135.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/121.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/109.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/137.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/123.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/080.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/094.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/043.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/057.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/056.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/042.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/095.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/081.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/122.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/136.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/132.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/126.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/085.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/091.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/046.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/052.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/053.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/047.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/090.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/084.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/127.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/133.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/125.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/131.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/119.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/092.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/086.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/051.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/045.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/079.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/078.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/044.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/050.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/087.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/093.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/118.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/130.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/124.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/143.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/037.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/023.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/022.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/036.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/142.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/140.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/008.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/020.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/034.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/035.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/021.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/009.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/141.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/151.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/145.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/025.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/031.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/019.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/018.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/030.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/024.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/144.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/150.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/146.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/032.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/026.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/027.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/033.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/lacrosse/147.jpg
#      TOTAL PROCESADO -> 151/151
# CAT: shuffleboard | OHE: -> 1
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/016.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/002.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/003.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/017.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/029.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/001.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/015.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/014.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/028.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/004.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/010.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/038.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/039.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/011.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/005.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/013.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/007.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/006.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/012.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/129.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/101.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/115.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/049.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/075.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/061.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/060.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/074.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/048.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/114.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/100.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/128.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/116.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/102.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/089.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/062.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/076.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/077.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/063.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/088.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/103.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/117.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/113.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/107.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/098.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/067.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/073.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/072.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/066.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/099.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/106.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/112.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/104.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/110.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/070.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/064.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/058.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/059.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/065.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/071.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/111.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/105.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/108.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/120.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/097.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/083.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/068.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/054.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/040.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/041.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/055.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/069.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/082.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/096.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/121.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/109.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/123.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/080.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/094.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/043.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/057.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/056.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/042.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/095.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/081.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/122.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/126.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/085.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/091.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/046.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/052.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/053.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/047.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/090.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/084.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/127.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/125.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/119.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/092.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/086.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/051.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/045.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/079.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/078.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/044.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/050.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/087.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/093.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/118.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/130.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/124.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/037.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/023.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/022.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/036.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/008.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/020.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/034.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/035.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/021.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/009.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/025.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/031.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/019.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/018.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/030.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/024.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/032.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/026.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/027.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/train/shuffleboard/033.jpg
#      TOTAL PROCESADO -> 130/130
# PREPROCESAMIENTO FINALIZADO CON ÉXITO!
# CAT: lacrosse | OHE: -> 0
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/lacrosse/4.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/lacrosse/5.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/lacrosse/2.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/lacrosse/3.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/lacrosse/1.jpg
#      TOTAL PROCESADO -> 5/5
# CAT: shuffleboard | OHE: -> 1
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/shuffleboard/4.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/shuffleboard/5.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/shuffleboard/2.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/shuffleboard/3.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/valid/shuffleboard/1.jpg
#      TOTAL PROCESADO -> 5/5
# PREPROCESAMIENTO FINALIZADO CON ÉXITO!
# CAT: lacrosse | OHE: -> 0
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/lacrosse/4.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/lacrosse/5.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/lacrosse/2.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/lacrosse/3.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/lacrosse/1.jpg
#      TOTAL PROCESADO -> 5/5
# CAT: shuffleboard | OHE: -> 1
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/shuffleboard/4.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/shuffleboard/5.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/shuffleboard/2.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/shuffleboard/3.jpg
#           PROC: /Users/albert99/Desktop/Proyectos/DATASETS/sports/test/shuffleboard/1.jpg
#      TOTAL PROCESADO -> 5/5
# PREPROCESAMIENTO FINALIZADO CON ÉXITO!

# %%
print("Tam. dataset entrenamiento: ", len(training_data)) # Tamano del dataset (cantidad de imágenes)
print("Tam. dataset validación: ", len(valid_data)) 
print("Tam. dataset test: ", len(test_data))
# Out:
# Tam. dataset entrenamiento:  281
# Tam. dataset validación:  10
# Tam. dataset test:  10

# %%
# Visualizamos la estructura de cada elemento de la lista de entrenamiento

print("Feature: ... " + str(training_data[0][0]) + " ... asociada a etiqueta -> " + str(training_data[0][1]))
# Out:
# Feature: ... [[126 150 152 ... 163 148 101]
#  [149 165 171 ... 140 134 111]
#  [160 170 158 ... 121 126 125]
#  ...
#  [ 89  98 100 ... 105  91  96]
#  [ 95  95  86 ...  86  85  99]
#  [ 86  97 110 ...  82  83  82]] ... asociada a etiqueta -> 0

# %%
# Barajar el dataset de entrenamiento (los otros no importan)

import random

random.shuffle(training_data)

# %%
# Comprobamos que está barajado (randomizado) mostrando sus etiquetas

for ejemplo in training_data[:10]: # solo los 10 primeros de la lista para simplificar
    print(ejemplo[1])
# Out:
# 1
# 1
# 0
# 0
# 1
# 0
# 1
# 1
# 1
# 0

# %%
# Separamos las imágenes y las etiquetas en dos listas distintas para cada set de datos

X_train = [] # set de datos de entrenamiento
y_train = []

X_valid = [] # set de datos de validación
y_valid = []

X_test = [] # set de datos de test
y_test = []

for features, label in training_data:
    X_train.append(features)
    y_train.append(label)
    
# Transformo entrenamiento a array numpy
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE, 1) # -1=tam.comodín, 1=escala grises (3=RGB)
y_train = np.array(y_train).reshape(-1)

for features, label in valid_data:
    X_valid.append(features)
    y_valid.append(label)
    
# Transformo validación a array numpy
X_valid = np.array(X_valid).reshape(-1, IMG_SIZE, IMG_SIZE, 1) 
y_valid = np.array(y_valid).reshape(-1)

for features, label in test_data:
    X_test.append(features)
    y_test.append(label)
    
# Transformo validación a array numpy
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y_test = np.array(y_test)

# %%
# Comprobamos la forma que tienen los sets de entrenamiento, validación y test

print(X_train.shape)
print(y_train.shape)

print(X_valid.shape)
print(y_valid.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (281, 100, 100, 1)
# (281,)
# (10, 100, 100, 1)
# (10,)
# (10, 100, 100, 1)
# (10,)

# %%
# Compruebo que el diccionario de categorías One Hot Enc. se ha creado correctamente

CATEGORIES_DICT
# Out:
# {'lacrosse': '0', 'shuffleboard': '1'}

# %%
# Escalamos las intensidades de los pixeles en el rango de 0-1 para simplificar

X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

# %%
# Compruebo que se ha normalizado correctamente
X_train
# Out:
# array([[[[0.09411765],
#          [0.10588235],
#          [0.10980392],
#          ...,
#          [0.10980392],
#          [0.08235294],
#          [0.11764706]],
#
#         [[0.10196078],
#          [0.12156863],
#          [0.11764706],
#          ...,
#          [0.11372549],
#          [0.09019608],
#          [0.09803922]],
#
#         [[0.11372549],
#          [0.1254902 ],
#          [0.12156863],
#          ...,
#          [0.11372549],
#          [0.10196078],
#          [0.09411765]],
#
#         ...,
#
#         [[0.06666667],
#          [0.06666667],
#          [0.06666667],
#          ...,
#          [0.06666667],
#          [0.06666667],
#          [0.06666667]],
#
#         [[0.07058824],
#          [0.0745098 ],
#          [0.0745098 ],
#          ...,
#          [0.06666667],
#          [0.06666667],
#          [0.06666667]],
#
#         [[0.06666667],
#          [0.07058824],
#          [0.07058824],
#          ...,
#          [0.07058824],
#          [0.07058824],
#          [0.07058824]]],
#
#
#        [[[0.11764706],
#          [0.11764706],
#          [0.11764706],
#          ...,
#          [0.12156863],
#          [0.12156863],
#          [0.12156863]],
#
#         [[0.12156863],
#          [0.11764706],
#          [0.12156863],
#          ...,
#          [0.12156863],
#          [0.12156863],
#          [0.12156863]],
#
#         [[0.1254902 ],
#          [0.12941176],
#          [0.12156863],
#          ...,
#          [0.12156863],
#          [0.12156863],
#          [0.12156863]],
#
#         ...,
#
#         [[0.15686275],
#          [0.16078431],
#          [0.16470588],
#          ...,
#          [0.10588235],
#          [0.10588235],
#          [0.10196078]],
#
#         [[0.1254902 ],
#          [0.12941176],
#          [0.12941176],
#          ...,
#          [0.12941176],
#          [0.12941176],
#          [0.1254902 ]],
#
#         [[0.11372549],
#          [0.11764706],
#          [0.12156863],
#          ...,
#          [0.11372549],
#          [0.11372549],
#          [0.11372549]]],
#
#
#        [[[0.29411765],
#          [0.48235294],
#          [0.41176471],
#          ...,
#          [0.05098039],
#          [0.04313725],
#          [0.04313725]],
#
#         [[0.41176471],
#          [0.28627451],
#          [0.31764706],
#          ...,
#          [0.0627451 ],
#          [0.0745098 ],
#          [0.05882353]],
#
#         [[0.36078431],
#          [0.29019608],
#          [0.30588235],
#          ...,
#          [0.25490196],
#          [0.39607843],
#          [0.35686275]],
#
#         ...,
#
#         [[0.4627451 ],
#          [0.66666667],
#          [0.62352941],
#          ...,
#          [0.89411765],
#          [0.91764706],
#          [0.67843137]],
#
#         [[0.4627451 ],
#          [0.63921569],
#          [0.62352941],
#          ...,
#          [0.82745098],
#          [0.84313725],
#          [0.87058824]],
#
#         [[0.55686275],
#          [0.59215686],
#          [0.59607843],
#          ...,
#          [0.80784314],
#          [0.6627451 ],
#          [0.82352941]]],
#
#
#        ...,
#
#
#        [[[0.25882353],
#          [0.36862745],
#          [0.50980392],
#          ...,
#          [0.07058824],
#          [0.03921569],
#          [0.00392157]],
#
#         [[0.3254902 ],
#          [0.5254902 ],
#          [0.70588235],
#          ...,
#          [0.0745098 ],
#          [0.02745098],
#          [0.00392157]],
#
#         [[0.34901961],
#          [0.55294118],
#          [0.69019608],
#          ...,
#          [0.06666667],
#          [0.04313725],
#          [0.00392157]],
#
#         ...,
#
#         [[0.45098039],
#          [0.46666667],
#          [0.48627451],
#          ...,
#          [0.4745098 ],
#          [0.47058824],
#          [0.45882353]],
#
#         [[0.47843137],
#          [0.45098039],
#          [0.47843137],
#          ...,
#          [0.47843137],
#          [0.52156863],
#          [0.47843137]],
#
#         [[0.4627451 ],
#          [0.4627451 ],
#          [0.46666667],
#          ...,
#          [0.48627451],
#          [0.48627451],
#          [0.47843137]]],
#
#
#        [[[0.40392157],
#          [0.41568627],
#          [0.4       ],
#          ...,
#          [0.49411765],
#          [0.46666667],
#          [0.4745098 ]],
#
#         [[0.37647059],
#          [0.4       ],
#          [0.37647059],
#          ...,
#          [0.44313725],
#          [0.42745098],
#          [0.41176471]],
#
#         [[0.37254902],
#          [0.36470588],
#          [0.38431373],
#          ...,
#          [0.45882353],
#          [0.45882353],
#          [0.46666667]],
#
#         ...,
#
#         [[0.38039216],
#          [0.34901961],
#          [0.38823529],
#          ...,
#          [0.41176471],
#          [0.34901961],
#          [0.50980392]],
#
#         [[0.40392157],
#          [0.38431373],
#          [0.36078431],
#          ...,
#          [0.45490196],
#          [0.45490196],
#          [0.32156863]],
#
#         [[0.42745098],
#          [0.44705882],
#          [0.37647059],
#          ...,
#          [0.43529412],
#          [0.41176471],
#          [0.39607843]]],
#
#
#        [[[0.48627451],
#          [0.48235294],
#          [0.46666667],
#          ...,
#          [0.15686275],
#          [0.16078431],
#          [0.1372549 ]],
#
#         [[0.43921569],
#          [0.42745098],
#          [0.4       ],
#          ...,
#          [0.15686275],
#          [0.11764706],
#          [0.05882353]],
#
#         [[0.37647059],
#          [0.35294118],
#          [0.31764706],
#          ...,
#          [0.10980392],
#          [0.0627451 ],
#          [0.14117647]],
#
#         ...,
#
#         [[0.51764706],
#          [0.49411765],
#          [0.54509804],
#          ...,
#          [0.56862745],
#          [0.5254902 ],
#          [0.52941176]],
#
#         [[0.5372549 ],
#          [0.54117647],
#          [0.49411765],
#          ...,
#          [0.56470588],
#          [0.59215686],
#          [0.57647059]],
#
#         [[0.54117647],
#          [0.55294118],
#          [0.5254902 ],
#          ...,
#          [0.55686275],
#          [0.57254902],
#          [0.57254902]]]])

# %% [markdown]
# ## Creación del modelo usando API secuencial
#
# Construcción de la red neuronal

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 1)),
    tf.keras.layers.Flatten(),  # Aplanar la imagen
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="softmax")  # 100 neuronas para 100 clases
])
# Out:
# 2024-02-27 18:58:19.119965: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 10000)             0
#
#  dense (Dense)               (None, 300)               3000300
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 100)               10100
#
# =================================================================
# Total params: 3,040,500
# Trainable params: 3,040,500
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### INFORMACIÓN ADICIONAL
#
# 1. **Clasificación Multiclase**:
#
# Las etiquetas son únicas y exclusivas para cada instancia.
#
# Se utiliza una función de activación softmax en la capa de salida para obtener probabilidades para cada clase.
# La función de pérdida comúnmente utilizada es **categorical_crossentropy**.
#
# En la salida, solo una de las neuronas de la capa de salida tendrá una activación alta, indicando la clase predicha para esa instancia.
#
# 2. **Clasificación de Etiquetas Múltiples**:
#
# Las etiquetas no son mutuamente excluyentes y una instancia puede tener múltiples etiquetas activas.
#
# Se utiliza una función de activación sigmoid en la capa de salida para obtener probabilidades independientes para cada clase.
# La función de pérdida comúnmente utilizada es **binary_crossentropy**.
#
# En la salida, cada neurona de la capa de salida representa una clase y puede tener una activación alta o baja independientemente de las otras neuronas, lo que permite que una instancia tenga múltiples clases activas.

# %% [markdown]
# ## Compilar el modelo
#
# Establecer la función de pérdida y el optimizador que se va a usar

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %% [markdown]
# ## Entrenamiento y evaluación del modelo

# %%
history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9000
# Epoch 2/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9000
# Epoch 3/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9000
# Epoch 4/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9000
# Epoch 5/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9000
# Epoch 6/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9000
# Epoch 7/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9000
# Epoch 8/30
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9000
# Epoch 9/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.8000
# Epoch 10/30
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9000
# Epoch 11/30
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.8000
# Epoch 12/30
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9000
# Epoch 13/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9000
# Epoch 14/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9000
# Epoch 15/30
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9000
# Epoch 16/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9000
# Epoch 17/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.8000
# Epoch 18/30
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.8000
# Epoch 19/30
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9000
# Epoch 20/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.8000
# Epoch 21/30
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9000
# Epoch 22/30

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 29], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2789 - accuracy: 0.8000
# [0.2789466977119446, 0.800000011920929]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


# Dataset de ropa

fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.


# Definir la arquitectura del modelo
model = models.Sequential([
    # Primera capa convolucional
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    
    # Segunda capa convolucional
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    # Tercera capa convolucional
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    # Capa de aplanamiento
    layers.Flatten(),
    
    # Capa densa con activación ReLU
    layers.Dense(256, activation='relu'),
    
    # Capa de salida con activación softmax para la clasificación multiclase
    layers.Dense(10, activation='softmax')
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Resumen del modelo
model.summary()

# Entrenamiento
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))

# Evaluación
model.evaluate(X_test, y_test)


import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 29], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.show()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_15 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_16 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 3, 3, 128)         73856
#
#  max_pooling2d_17 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 128)               0
#
#  dense_22 (Dense)            (None, 256)               33024
#
#  dense_23 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 128,266
# Trainable params: 128,266
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1719/1719 [==============================] - 25s 15ms/step - loss: 0.5788 - accuracy: 0.7884 - val_loss: 0.4181 - val_accuracy: 0.8434
# Epoch 2/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.3917 - accuracy: 0.8553 - val_loss: 0.3904 - val_accuracy: 0.8556
# Epoch 3/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.3363 - accuracy: 0.8745 - val_loss: 0.3257 - val_accuracy: 0.8806
# Epoch 4/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.2964 - accuracy: 0.8901 - val_loss: 0.2962 - val_accuracy: 0.8904
# Epoch 5/20
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.2646 - accuracy: 0.9013 - val_loss: 0.2976 - val_accuracy: 0.8918
# Epoch 6/20
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.2429 - accuracy: 0.9095 - val_loss: 0.3062 - val_accuracy: 0.8908
# Epoch 7/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.2207 - accuracy: 0.9163 - val_loss: 0.2851 - val_accuracy: 0.8958
# Epoch 8/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.2034 - accuracy: 0.9234 - val_loss: 0.3140 - val_accuracy: 0.8896
# Epoch 9/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.1864 - accuracy: 0.9301 - val_loss: 0.2961 - val_accuracy: 0.8944
# Epoch 10/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.1715 - accuracy: 0.9345 - val_loss: 0.2904 - val_accuracy: 0.8980
# Epoch 11/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.1579 - accuracy: 0.9396 - val_loss: 0.2992 - val_accuracy: 0.9050
# Epoch 12/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.1451 - accuracy: 0.9442 - val_loss: 0.3198 - val_accuracy: 0.9012
# Epoch 13/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.1364 - accuracy: 0.9477 - val_loss: 0.3179 - val_accuracy: 0.9028
# Epoch 14/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.1244 - accuracy: 0.9530 - val_loss: 0.3770 - val_accuracy: 0.8950
# Epoch 15/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.1164 - accuracy: 0.9550 - val_loss: 0.3766 - val_accuracy: 0.8976
# Epoch 16/20
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.1099 - accuracy: 0.9583 - val_loss: 0.3565 - val_accuracy: 0.9040
# Epoch 17/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.1003 - accuracy: 0.9610 - val_loss: 0.3807 - val_accuracy: 0.9004
# Epoch 18/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0976 - accuracy: 0.9632 - val_loss: 0.4148 - val_accuracy: 0.8994
# Epoch 19/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.0898 - accuracy: 0.9657 - val_loss: 0.4459 - val_accuracy: 0.9012
# Epoch 20/20
# 1719/1719 [==============================] - 25s 15ms/step - loss: 0.0850 - accuracy: 0.9681 - val_loss: 0.4602 - val_accuracy: 0.8998
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5002 - accuracy: 0.8951

# %%
X_new= X_test[:3]
y_proba = model.predict(X_new)
y_proba.round(2)

y_pred = y_proba.argmax(axis=-1)
y_pred
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([9, 2, 1])

# %% [markdown]
# ## Tensorboard

# %%
from pathlib import Path
from time import strftime

def get_run_logdir(root_logdir="my_logs"):
    return Path(root_logdir) / strftime("run_%Y_%m_%d_%H_%M_%S")

run_logdir = get_run_logdir()

# %%
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir, profile_batch=(100, 200))

history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid), callbacks=[tensorboard_cb])
# Out:
# 2024-02-26 17:04:57.780977: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2024-02-26 17:04:57.780998: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2024-02-26 17:04:57.781859: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# Epoch 1/20
#  113/1719 [>.............................] - ETA: 20s - loss: 0.0711 - accuracy: 0.9718
# 2024-02-26 17:04:59.304079: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2024-02-26 17:04:59.304101: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
#  204/1719 [==>...........................] - ETA: 20s - loss: 0.0722 - accuracy: 0.9732
# 2024-02-26 17:05:00.610734: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2024-02-26 17:05:00.649924: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2024-02-26 17:05:00.690378: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00
#
# 2024-02-26 17:05:00.712701: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.trace.json.gz
# 2024-02-26 17:05:00.742043: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00
#
# 2024-02-26 17:05:00.742259: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.memory_profile.json.gz
# 2024-02-26 17:05:00.744757: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00
# Dumped tool data for xplane.pb to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.xplane.pb
# Dumped tool data for overview_page.pb to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.overview_page.pb
# Dumped tool data for input_pipeline.pb to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to my_logs/run_2024_02_26_17_02_51/plugins/profile/2024_02_26_17_05_00/MBP.local.kernel_stats.pb
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0811 - accuracy: 0.9692 - val_loss: 0.4977 - val_accuracy: 0.8966
# Epoch 2/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0751 - accuracy: 0.9709 - val_loss: 0.4983 - val_accuracy: 0.8950
# Epoch 3/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0716 - accuracy: 0.9732 - val_loss: 0.5282 - val_accuracy: 0.8958
# Epoch 4/20
# 1719/1719 [==============================] - 25s 15ms/step - loss: 0.0711 - accuracy: 0.9726 - val_loss: 0.5309 - val_accuracy: 0.8978
# Epoch 5/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0644 - accuracy: 0.9758 - val_loss: 0.5226 - val_accuracy: 0.8976
# Epoch 6/20
# 1719/1719 [==============================] - 23s 14ms/step - loss: 0.0653 - accuracy: 0.9752 - val_loss: 0.5363 - val_accuracy: 0.8994
# Epoch 7/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0602 - accuracy: 0.9776 - val_loss: 0.5613 - val_accuracy: 0.8960
# Epoch 8/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0611 - accuracy: 0.9768 - val_loss: 0.6032 - val_accuracy: 0.8950
# Epoch 9/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0627 - accuracy: 0.9768 - val_loss: 0.5883 - val_accuracy: 0.8912
# Epoch 10/20
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0511 - accuracy: 0.9816 - val_loss: 0.5866 - val_accuracy: 0.8898
# Epoch 11/20
# 1719/1719 [==============================] - 25s 14ms/step - loss: 0.0557 - accuracy: 0.9790 - val_loss: 0.6516 - val_accuracy: 0.8932
# Epoch 12/20
# 1719/1719 [==============================] - 23s 14ms/step - loss: 0.0523 - accuracy: 0.9800 - val_loss: 0.6565 - val_accuracy: 0.8948
# Epoch 13/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0487 - accuracy: 0.9822 - val_loss: 0.6805 - val_accuracy: 0.8972
# Epoch 14/20
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0499 - accuracy: 0.9819 - val_loss: 0.6620 - val_accuracy: 0.8940
# Epoch 15/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0446 - accuracy: 0.9833 - val_loss: 0.7479 - val_accuracy: 0.8936
# Epoch 16/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0512 - accuracy: 0.9816 - val_loss: 0.6777 - val_accuracy: 0.8960
# Epoch 17/20
# 1719/1719 [==============================] - 25s 15ms/step - loss: 0.0470 - accuracy: 0.9829 - val_loss: 0.6773 - val_accuracy: 0.8914
# Epoch 18/20
# 1719/1719 [==============================] - 24s 14ms/step - loss: 0.0459 - accuracy: 0.9835 - val_loss: 0.6956 - val_accuracy: 0.9002
# Epoch 19/20
# 1719/1719 [==============================] - 25s 15ms/step - loss: 0.0415 - accuracy: 0.9844 - val_loss: 0.7239 - val_accuracy: 0.8936
# Epoch 20/20
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0478 - accuracy: 0.9831 - val_loss: 0.7622 - val_accuracy: 0.8960

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_logs
# Out:
#       <iframe id="tensorboard-frame-8c3abdf17029b1f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8c3abdf17029b1f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
